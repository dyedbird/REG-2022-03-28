# %% [markdown]
# # Russian Premier League  - Pipeline

# %%
import requests, bs4
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
url = 'https://fbref.com/en/comps/30/Russian-Premier-League-Stats#results112821_overall'
response = requests.get(url)
status = response.status_code
if status == 200:
  page = response.text
  soup = bs(page)
else:
  print(f"Oops! Received status code {status}")

# %%
league_table_22 = []

ranking= [rank['csk'] for rank in soup.find_all\
                            ('th', attrs={'scope':'row','data-stat':'rank'})][0:20]

squad = [team.text.strip() for team in soup.find_all('td',attrs={'data-stat':'squad'})][0:20]

wins = [win.text for win in soup.find_all('td',attrs = {'data-stat':'wins'})][0:20]

draws = [draw.text for draw in soup.find_all('td',attrs = {'data-stat':'draws'})][0:20]

losses = [loss.text for loss in soup.find_all('td',attrs = {'data-stat':'losses'})][0:20]

goals_for = [goal.text for goal in soup.find_all('td',\
                                                    attrs = {'data-stat':'goals_for'})][0:20]

goals_against = [goal.text for goal in soup.find_all\
                                         ('td',attrs = {'data-stat':'goals_against'})][0:20]

points = [point.text for point in soup.find_all('td',attrs = {'data-stat':'points'})][0:20]

x_goals = [goal.text for goal in soup.find_all('td',attrs = {'data-stat':'xg_for'})][0:20]

x_goals_A = [goal.text for goal in soup.find_all\
                                             ('td',attrs = {'data-stat':'xg_against'})][0:20]

attendance = [att.text for att in soup.find_all\
                                    ('td',attrs = {'data-stat':'attendance_per_g'})][0:20]


for num in range(0,16):
    my_dict={'RANK':ranking[num],'TEAM':squad[num], 'W':wins[num], 'D':draws[num],\
             'L':losses[num], 'GF':goals_for[num], 'GA':goals_against[num],\
             'PTS':points[num],'ATT':attendance[num]}
    league_table_22.append(my_dict)
    my_dict = dict()

league_table_22
# Out:
# [{'RANK': '1',
#   'TEAM': 'Zenit',
#   'W': '19',
#   'D': '8',
#   'L': '3',
#   'GF': '66',
#   'GA': '28',
#   'PTS': '65',
#   'ATT': '20,401'},
#  {'RANK': '2',
#   'TEAM': 'Sochi',
#   'W': '17',
#   'D': '5',
#   'L': '8',
#   'GF': '54',
#   'GA': '30',
#   'PTS': '56',
#   'ATT': '4,411'},
#  {'RANK': '3',
#   'TEAM': 'Dynamo Mosc',
#   'W': '16',
#   'D': '5',
#   'L': '9',
#   'GF': '53',
#   'GA': '41',
#   'PTS': '53',
#   'ATT': '10,554'},
#  {'RANK': '4',
#   'TEAM': 'Krasnodar',
#   'W': '14',
#   'D': '8',
#   'L': '8',
#   'GF': '42',
#   'GA': '30',
#   'PTS': '50',
#   'ATT': '11,448'},
#  {'RANK': '5',
#   'TEAM': 'CSKA Moscow',
#   'W': '15',
#   'D': '5',
#   'L': '10',
#   'GF': '42',
#   'GA': '29',
#   'PTS': '50',
#   'ATT': '7,236'},
#  {'RANK': '6',
#   'TEAM': 'Loko Moscow',
#   'W': '13',
#   'D': '9',
#   'L': '8',
#   'GF': '43',
#   'GA': '39',
#   'PTS': '48',
#   'ATT': '6,046'},
#  {'RANK': '7',
#   'TEAM': 'Akhmat Grozny',
#   'W': '13',
# ...

# %%
RPL_22_table_df = pd.DataFrame(league_table_22)
RPL_22_table_df.style.hide_index()
# Out:
# /tmp/ipykernel_16884/2545868134.py:2: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   RPL_22_table_df.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_7a5d4">
#   <thead>
#     <tr>
#       <th id="T_7a5d4_level0_col0" class="col_heading level0 col0" >RANK</th>
#       <th id="T_7a5d4_level0_col1" class="col_heading level0 col1" >TEAM</th>
#       <th id="T_7a5d4_level0_col2" class="col_heading level0 col2" >W</th>
#       <th id="T_7a5d4_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_7a5d4_level0_col4" class="col_heading level0 col4" >L</th>
#       <th id="T_7a5d4_level0_col5" class="col_heading level0 col5" >GF</th>
#       <th id="T_7a5d4_level0_col6" class="col_heading level0 col6" >GA</th>
#       <th id="T_7a5d4_level0_col7" class="col_heading level0 col7" >PTS</th>
#       <th id="T_7a5d4_level0_col8" class="col_heading level0 col8" >ATT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
url = 'https://fbref.com/en/comps/30/10742/2020-2021-Russian-Premier-League-Stats#results107421_overall'
response = requests.get(url)
status = response.status_code
if status == 200:
  page = response.text
  soup = bs(page)
else:
  print(f"Oops! Received status code {status}")

# %%
league_table_21 = []

ranking= [rank['csk'] for rank in soup.find_all\
                            ('th', attrs={'scope':'row','data-stat':'rank'})][0:20]

squad = [team.text.strip() for team in soup.find_all('td',attrs={'data-stat':'squad'})][0:20]

wins = [win.text for win in soup.find_all('td',attrs = {'data-stat':'wins'})][0:20]

draws = [draw.text for draw in soup.find_all('td',attrs = {'data-stat':'draws'})][0:20]

losses = [loss.text for loss in soup.find_all('td',attrs = {'data-stat':'losses'})][0:20]

goals_for = [goal.text for goal in soup.find_all('td',\
                                                    attrs = {'data-stat':'goals_for'})][0:20]

goals_against = [goal.text for goal in soup.find_all\
                                         ('td',attrs = {'data-stat':'goals_against'})][0:20]

points = [point.text for point in soup.find_all('td',attrs = {'data-stat':'points'})][0:20]

x_goals = [goal.text for goal in soup.find_all('td',attrs = {'data-stat':'xg_for'})][0:20]

x_goals_A = [goal.text for goal in soup.find_all\
                                             ('td',attrs = {'data-stat':'xg_against'})][0:20]

attendance = [att.text for att in soup.find_all\
                                    ('td',attrs = {'data-stat':'attendance_per_g'})][0:20]


for num in range(0,16):
    my_dict={'RANK':ranking[num],'TEAM':squad[num], 'W':wins[num], 'D':draws[num],\
             'L':losses[num], 'GF':goals_for[num], 'GA':goals_against[num],\
             'PTS':points[num],'ATT':attendance[num]}
    league_table_21.append(my_dict)
    my_dict = dict()

league_table_21
# Out:
# [{'RANK': '1',
#   'TEAM': 'Zenit',
#   'W': '19',
#   'D': '8',
#   'L': '3',
#   'GF': '76',
#   'GA': '26',
#   'PTS': '65',
#   'ATT': '17,737'},
#  {'RANK': '2',
#   'TEAM': 'Spartak Moscow',
#   'W': '17',
#   'D': '6',
#   'L': '7',
#   'GF': '56',
#   'GA': '37',
#   'PTS': '57',
#   'ATT': '8,683'},
#  {'RANK': '3',
#   'TEAM': 'Loko Moscow',
#   'W': '17',
#   'D': '5',
#   'L': '8',
#   'GF': '45',
#   'GA': '35',
#   'PTS': '56',
#   'ATT': '6,560'},
#  {'RANK': '4',
#   'TEAM': 'Rubin Kazan',
#   'W': '16',
#   'D': '5',
#   'L': '9',
#   'GF': '42',
#   'GA': '33',
#   'PTS': '53',
#   'ATT': '6,832'},
#  {'RANK': '5',
#   'TEAM': 'Sochi',
#   'W': '15',
#   'D': '8',
#   'L': '7',
#   'GF': '49',
#   'GA': '33',
#   'PTS': '53',
#   'ATT': '5,023'},
#  {'RANK': '6',
#   'TEAM': 'CSKA Moscow',
#   'W': '15',
#   'D': '5',
#   'L': '10',
#   'GF': '51',
#   'GA': '33',
#   'PTS': '50',
#   'ATT': '8,185'},
#  {'RANK': '7',
#   'TEAM': 'Dynamo Mosc',
#   'W': '15',
# ...

# %%
RPL_21_table_df = pd.DataFrame(league_table_21)
RPL_21_table_df.style.hide_index()
# Out:
# /tmp/ipykernel_16884/1039618281.py:2: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   RPL_21_table_df.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_756ee">
#   <thead>
#     <tr>
#       <th id="T_756ee_level0_col0" class="col_heading level0 col0" >RANK</th>
#       <th id="T_756ee_level0_col1" class="col_heading level0 col1" >TEAM</th>
#       <th id="T_756ee_level0_col2" class="col_heading level0 col2" >W</th>
#       <th id="T_756ee_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_756ee_level0_col4" class="col_heading level0 col4" >L</th>
#       <th id="T_756ee_level0_col5" class="col_heading level0 col5" >GF</th>
#       <th id="T_756ee_level0_col6" class="col_heading level0 col6" >GA</th>
#       <th id="T_756ee_level0_col7" class="col_heading level0 col7" >PTS</th>
#       <th id="T_756ee_level0_col8" class="col_heading level0 col8" >ATT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
url = 'https://fbref.com/en/comps/30/3285/2019-2020-Russian-Premier-League-Stats#results32851_overall'

response = requests.get(url)
status = response.status_code
if status == 200:
  page = response.text
  soup = bs(page)
else:
  print(f"Oops! Received status code {status}")

# %%
league_table_20 = []

ranking= [rank['csk'] for rank in soup.find_all\
                            ('th', attrs={'scope':'row','data-stat':'rank'})][0:20]

squad = [team.text.strip() for team in soup.find_all('td',attrs={'data-stat':'squad'})][0:20]

wins = [win.text for win in soup.find_all('td',attrs = {'data-stat':'wins'})][0:20]

draws = [draw.text for draw in soup.find_all('td',attrs = {'data-stat':'draws'})][0:20]

losses = [loss.text for loss in soup.find_all('td',attrs = {'data-stat':'losses'})][0:20]

goals_for = [goal.text for goal in soup.find_all('td',\
                                                    attrs = {'data-stat':'goals_for'})][0:20]

goals_against = [goal.text for goal in soup.find_all\
                                         ('td',attrs = {'data-stat':'goals_against'})][0:20]

points = [point.text for point in soup.find_all('td',attrs = {'data-stat':'points'})][0:20]

x_goals = [goal.text for goal in soup.find_all('td',attrs = {'data-stat':'xg_for'})][0:20]

x_goals_A = [goal.text for goal in soup.find_all\
                                             ('td',attrs = {'data-stat':'xg_against'})][0:20]

attendance = [att.text for att in soup.find_all\
                                    ('td',attrs = {'data-stat':'attendance_per_g'})][0:20]


for num in range(0,16):
    my_dict={'RANK':ranking[num],'TEAM':squad[num], 'W':wins[num], 'D':draws[num],\
             'L':losses[num], 'GF':goals_for[num], 'GA':goals_against[num],\
             'PTS':points[num],'ATT':attendance[num]}
    league_table_20.append(my_dict)
    my_dict = dict()

league_table_20
# Out:
# [{'RANK': '1',
#   'TEAM': 'Zenit',
#   'W': '22',
#   'D': '6',
#   'L': '2',
#   'GF': '65',
#   'GA': '18',
#   'PTS': '72',
#   'ATT': '39,012'},
#  {'RANK': '2',
#   'TEAM': 'Loko Moscow',
#   'W': '16',
#   'D': '9',
#   'L': '5',
#   'GF': '41',
#   'GA': '29',
#   'PTS': '57',
#   'ATT': '10,797'},
#  {'RANK': '3',
#   'TEAM': 'Krasnodar',
#   'W': '14',
#   'D': '10',
#   'L': '6',
#   'GF': '49',
#   'GA': '30',
#   'PTS': '52',
#   'ATT': '21,524'},
#  {'RANK': '4',
#   'TEAM': 'CSKA Moscow',
#   'W': '14',
#   'D': '8',
#   'L': '8',
#   'GF': '43',
#   'GA': '29',
#   'PTS': '50',
#   'ATT': '12,149'},
#  {'RANK': '5',
#   'TEAM': 'Rostov',
#   'W': '12',
#   'D': '9',
#   'L': '9',
#   'GF': '45',
#   'GA': '50',
#   'PTS': '45',
#   'ATT': '21,845'},
#  {'RANK': '6',
#   'TEAM': 'Dynamo Mosc',
#   'W': '11',
#   'D': '8',
#   'L': '11',
#   'GF': '27',
#   'GA': '30',
#   'PTS': '41',
#   'ATT': '11,034'},
#  {'RANK': '7',
#   'TEAM': 'Spartak Moscow',
#   'W': '11',
# ...

# %%
RPL_20_table_df = pd.DataFrame(league_table_20)
RPL_20_table_df.style.hide_index()
# Out:
# /tmp/ipykernel_16884/1568553014.py:2: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   RPL_20_table_df.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_7a50a">
#   <thead>
#     <tr>
#       <th id="T_7a50a_level0_col0" class="col_heading level0 col0" >RANK</th>
#       <th id="T_7a50a_level0_col1" class="col_heading level0 col1" >TEAM</th>
#       <th id="T_7a50a_level0_col2" class="col_heading level0 col2" >W</th>
#       <th id="T_7a50a_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_7a50a_level0_col4" class="col_heading level0 col4" >L</th>
#       <th id="T_7a50a_level0_col5" class="col_heading level0 col5" >GF</th>
#       <th id="T_7a50a_level0_col6" class="col_heading level0 col6" >GA</th>
#       <th id="T_7a50a_level0_col7" class="col_heading level0 col7" >PTS</th>
#       <th id="T_7a50a_level0_col8" class="col_heading level0 col8" >ATT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
url = 'https://fbref.com/en/comps/30/2371/2018-2019-Russian-Premier-League-Stats#results23711_overall'

response = requests.get(url)
status = response.status_code
if status == 200:
  page = response.text
  soup = bs(page)
else:
  print(f"Oops! Received status code {status}")

# %%
league_table_19 = []

ranking= [rank['csk'] for rank in soup.find_all\
                            ('th', attrs={'scope':'row','data-stat':'rank'})][0:20]

squad = [team.text.strip() for team in soup.find_all('td',attrs={'data-stat':'squad'})][0:20]

wins = [win.text for win in soup.find_all('td',attrs = {'data-stat':'wins'})][0:20]

draws = [draw.text for draw in soup.find_all('td',attrs = {'data-stat':'draws'})][0:20]

losses = [loss.text for loss in soup.find_all('td',attrs = {'data-stat':'losses'})][0:20]

goals_for = [goal.text for goal in soup.find_all('td',\
                                                    attrs = {'data-stat':'goals_for'})][0:20]

goals_against = [goal.text for goal in soup.find_all\
                                         ('td',attrs = {'data-stat':'goals_against'})][0:20]

points = [point.text for point in soup.find_all('td',attrs = {'data-stat':'points'})][0:20]

x_goals = [goal.text for goal in soup.find_all('td',attrs = {'data-stat':'xg_for'})][0:20]

x_goals_A = [goal.text for goal in soup.find_all\
                                             ('td',attrs = {'data-stat':'xg_against'})][0:20]

attendance = [att.text for att in soup.find_all\
                                    ('td',attrs = {'data-stat':'attendance_per_g'})][0:20]


for num in range(0,16):
    my_dict={'RANK':ranking[num],'TEAM':squad[num], 'W':wins[num], 'D':draws[num],\
             'L':losses[num], 'GF':goals_for[num], 'GA':goals_against[num],\
             'PTS':points[num],'ATT':attendance[num]}
    league_table_19.append(my_dict)
    my_dict = dict()

league_table_19
# Out:
# [{'RANK': '1',
#   'TEAM': 'Zenit',
#   'W': '20',
#   'D': '4',
#   'L': '6',
#   'GF': '57',
#   'GA': '29',
#   'PTS': '64',
#   'ATT': '48,122'},
#  {'RANK': '2',
#   'TEAM': 'Loko Moscow',
#   'W': '16',
#   'D': '8',
#   'L': '6',
#   'GF': '45',
#   'GA': '28',
#   'PTS': '56',
#   'ATT': '15,045'},
#  {'RANK': '3',
#   'TEAM': 'Krasnodar',
#   'W': '16',
#   'D': '8',
#   'L': '6',
#   'GF': '55',
#   'GA': '23',
#   'PTS': '56',
#   'ATT': '25,947'},
#  {'RANK': '4',
#   'TEAM': 'CSKA Moscow',
#   'W': '14',
#   'D': '9',
#   'L': '7',
#   'GF': '46',
#   'GA': '23',
#   'PTS': '51',
#   'ATT': '18,922'},
#  {'RANK': '5',
#   'TEAM': 'Spartak Moscow',
#   'W': '14',
#   'D': '7',
#   'L': '9',
#   'GF': '36',
#   'GA': '31',
#   'PTS': '49',
#   'ATT': '31,420'},
#  {'RANK': '6',
#   'TEAM': 'Arsenal Tula',
#   'W': '12',
#   'D': '10',
#   'L': '8',
#   'GF': '40',
#   'GA': '33',
#   'PTS': '46',
#   'ATT': '11,561'},
#  {'RANK': '7',
#   'TEAM': 'Orenburg',
# ...

# %%
RPL_19_table_df = pd.DataFrame(league_table_19)
RPL_19_table_df.style.hide_index()
# Out:
# /tmp/ipykernel_16884/1157542996.py:2: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   RPL_19_table_df.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_df14b">
#   <thead>
#     <tr>
#       <th id="T_df14b_level0_col0" class="col_heading level0 col0" >RANK</th>
#       <th id="T_df14b_level0_col1" class="col_heading level0 col1" >TEAM</th>
#       <th id="T_df14b_level0_col2" class="col_heading level0 col2" >W</th>
#       <th id="T_df14b_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_df14b_level0_col4" class="col_heading level0 col4" >L</th>
#       <th id="T_df14b_level0_col5" class="col_heading level0 col5" >GF</th>
#       <th id="T_df14b_level0_col6" class="col_heading level0 col6" >GA</th>
#       <th id="T_df14b_level0_col7" class="col_heading level0 col7" >PTS</th>
#       <th id="T_df14b_level0_col8" class="col_heading level0 col8" >ATT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
url = 'https://fbref.com/en/comps/30/1646/2017-2018-Russian-Premier-League-Stats#results16461_overall'

response = requests.get(url)
status = response.status_code
if status == 200:
  page = response.text
  soup = bs(page)
else:
  print(f"Oops! Received status code {status}")

# %%
league_table_18 = []

ranking= [rank['csk'] for rank in soup.find_all\
                            ('th', attrs={'scope':'row','data-stat':'rank'})][0:20]

squad = [team.text.strip() for team in soup.find_all('td',attrs={'data-stat':'squad'})][0:20]

wins = [win.text for win in soup.find_all('td',attrs = {'data-stat':'wins'})][0:20]

draws = [draw.text for draw in soup.find_all('td',attrs = {'data-stat':'draws'})][0:20]

losses = [loss.text for loss in soup.find_all('td',attrs = {'data-stat':'losses'})][0:20]

goals_for = [goal.text for goal in soup.find_all('td',\
                                                    attrs = {'data-stat':'goals_for'})][0:20]

goals_against = [goal.text for goal in soup.find_all\
                                         ('td',attrs = {'data-stat':'goals_against'})][0:20]

points = [point.text for point in soup.find_all('td',attrs = {'data-stat':'points'})][0:20]

x_goals = [goal.text for goal in soup.find_all('td',attrs = {'data-stat':'xg_for'})][0:20]

x_goals_A = [goal.text for goal in soup.find_all\
                                             ('td',attrs = {'data-stat':'xg_against'})][0:20]

attendance = [att.text for att in soup.find_all\
                                    ('td',attrs = {'data-stat':'attendance_per_g'})][0:20]


for num in range(0,16):
    my_dict={'RANK':ranking[num],'TEAM':squad[num], 'W':wins[num], 'D':draws[num],\
             'L':losses[num], 'GF':goals_for[num], 'GA':goals_against[num],\
             'PTS':points[num],'ATT':attendance[num]}
    league_table_18.append(my_dict)
    my_dict = dict()

league_table_18
# Out:
# [{'RANK': '1',
#   'TEAM': 'Loko Moscow',
#   'W': '18',
#   'D': '6',
#   'L': '6',
#   'GF': '41',
#   'GA': '21',
#   'PTS': '60',
#   'ATT': '12,708'},
#  {'RANK': '2',
#   'TEAM': 'CSKA Moscow',
#   'W': '17',
#   'D': '7',
#   'L': '6',
#   'GF': '49',
#   'GA': '23',
#   'PTS': '58',
#   'ATT': '15,605'},
#  {'RANK': '3',
#   'TEAM': 'Spartak Moscow',
#   'W': '16',
#   'D': '8',
#   'L': '6',
#   'GF': '51',
#   'GA': '32',
#   'PTS': '56',
#   'ATT': '30,189'},
#  {'RANK': '4',
#   'TEAM': 'Krasnodar',
#   'W': '16',
#   'D': '6',
#   'L': '8',
#   'GF': '46',
#   'GA': '30',
#   'PTS': '54',
#   'ATT': '25,032'},
#  {'RANK': '5',
#   'TEAM': 'Zenit',
#   'W': '14',
#   'D': '11',
#   'L': '5',
#   'GF': '46',
#   'GA': '21',
#   'PTS': '53',
#   'ATT': '43,963'},
#  {'RANK': '6',
#   'TEAM': 'Ufa',
#   'W': '11',
#   'D': '10',
#   'L': '9',
#   'GF': '34',
#   'GA': '30',
#   'PTS': '43',
#   'ATT': '6,916'},
#  {'RANK': '7',
#   'TEAM': 'Arsenal Tula',
#   'W': '12',
# ...

# %%
RPL_18_table_df = pd.DataFrame(league_table_18)
RPL_18_table_df.style.hide_index()
# Out:
# /tmp/ipykernel_16884/1738053099.py:2: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   RPL_18_table_df.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_2acee">
#   <thead>
#     <tr>
#       <th id="T_2acee_level0_col0" class="col_heading level0 col0" >RANK</th>
#       <th id="T_2acee_level0_col1" class="col_heading level0 col1" >TEAM</th>
#       <th id="T_2acee_level0_col2" class="col_heading level0 col2" >W</th>
#       <th id="T_2acee_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_2acee_level0_col4" class="col_heading level0 col4" >L</th>
#       <th id="T_2acee_level0_col5" class="col_heading level0 col5" >GF</th>
#       <th id="T_2acee_level0_col6" class="col_heading level0 col6" >GA</th>
#       <th id="T_2acee_level0_col7" class="col_heading level0 col7" >PTS</th>
#       <th id="T_2acee_level0_col8" class="col_heading level0 col8" >ATT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
url = 'https://fbref.com/en/comps/30/1541/2016-2017-Russian-Premier-League-Stats#results15411_overall'

response = requests.get(url)
status = response.status_code
if status == 200:
  page = response.text
  soup = bs(page)
else:
  print(f"Oops! Received status code {status}")

# %%
league_table_17 = []

ranking= [rank['csk'] for rank in soup.find_all\
                            ('th', attrs={'scope':'row','data-stat':'rank'})][0:20]

squad = [team.text.strip() for team in soup.find_all('td',attrs={'data-stat':'squad'})][0:20]

wins = [win.text for win in soup.find_all('td',attrs = {'data-stat':'wins'})][0:20]

draws = [draw.text for draw in soup.find_all('td',attrs = {'data-stat':'draws'})][0:20]

losses = [loss.text for loss in soup.find_all('td',attrs = {'data-stat':'losses'})][0:20]

goals_for = [goal.text for goal in soup.find_all('td',\
                                                    attrs = {'data-stat':'goals_for'})][0:20]

goals_against = [goal.text for goal in soup.find_all\
                                         ('td',attrs = {'data-stat':'goals_against'})][0:20]

points = [point.text for point in soup.find_all('td',attrs = {'data-stat':'points'})][0:20]

x_goals = [goal.text for goal in soup.find_all('td',attrs = {'data-stat':'xg_for'})][0:20]

x_goals_A = [goal.text for goal in soup.find_all\
                                             ('td',attrs = {'data-stat':'xg_against'})][0:20]

attendance = [att.text for att in soup.find_all\
                                    ('td',attrs = {'data-stat':'attendance_per_g'})][0:20]


for num in range(0,16):
    my_dict={'RANK':ranking[num],'TEAM':squad[num], 'W':wins[num], 'D':draws[num],\
             'L':losses[num], 'GF':goals_for[num], 'GA':goals_against[num],\
             'PTS':points[num],'ATT':attendance[num]}
    league_table_17.append(my_dict)
    my_dict = dict()

league_table_17
# Out:
# [{'RANK': '1',
#   'TEAM': 'Spartak Moscow',
#   'W': '22',
#   'D': '3',
#   'L': '5',
#   'GF': '46',
#   'GA': '27',
#   'PTS': '69',
#   'ATT': '32,760'},
#  {'RANK': '2',
#   'TEAM': 'CSKA Moscow',
#   'W': '18',
#   'D': '8',
#   'L': '4',
#   'GF': '47',
#   'GA': '15',
#   'PTS': '62',
#   'ATT': '14,454'},
#  {'RANK': '3',
#   'TEAM': 'Zenit',
#   'W': '18',
#   'D': '7',
#   'L': '5',
#   'GF': '50',
#   'GA': '19',
#   'PTS': '61',
#   'ATT': '18,557'},
#  {'RANK': '4',
#   'TEAM': 'Krasnodar',
#   'W': '12',
#   'D': '13',
#   'L': '5',
#   'GF': '40',
#   'GA': '22',
#   'PTS': '49',
#   'ATT': '15,886'},
#  {'RANK': '5',
#   'TEAM': 'Terek Grozny',
#   'W': '14',
#   'D': '6',
#   'L': '10',
#   'GF': '38',
#   'GA': '35',
#   'PTS': '48',
#   'ATT': '15,230'},
#  {'RANK': '6',
#   'TEAM': 'Rostov',
#   'W': '13',
#   'D': '9',
#   'L': '8',
#   'GF': '36',
#   'GA': '18',
#   'PTS': '48',
#   'ATT': '10,385'},
#  {'RANK': '7',
#   'TEAM': 'Ufa',
#   'W': '12',
# ...

# %%
RPL_17_table_df = pd.DataFrame(league_table_17)
RPL_17_table_df.style.hide_index()
# Out:
# /tmp/ipykernel_16884/4076290616.py:2: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   RPL_17_table_df.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_a7978">
#   <thead>
#     <tr>
#       <th id="T_a7978_level0_col0" class="col_heading level0 col0" >RANK</th>
#       <th id="T_a7978_level0_col1" class="col_heading level0 col1" >TEAM</th>
#       <th id="T_a7978_level0_col2" class="col_heading level0 col2" >W</th>
#       <th id="T_a7978_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_a7978_level0_col4" class="col_heading level0 col4" >L</th>
#       <th id="T_a7978_level0_col5" class="col_heading level0 col5" >GF</th>
#       <th id="T_a7978_level0_col6" class="col_heading level0 col6" >GA</th>
#       <th id="T_a7978_level0_col7" class="col_heading level0 col7" >PTS</th>
#       <th id="T_a7978_level0_col8" class="col_heading level0 col8" >ATT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
url = 'https://fbref.com/en/comps/30/1482/2015-2016-Russian-Premier-League-Stats#results14821_overall'

response = requests.get(url)
status = response.status_code
if status == 200:
  page = response.text
  soup = bs(page)
else:
  print(f"Oops! Received status code {status}")

# %%
league_table_16 = []

ranking= [rank['csk'] for rank in soup.find_all\
                            ('th', attrs={'scope':'row','data-stat':'rank'})][0:20]

squad = [team.text.strip() for team in soup.find_all('td',attrs={'data-stat':'squad'})][0:20]

wins = [win.text for win in soup.find_all('td',attrs = {'data-stat':'wins'})][0:20]

draws = [draw.text for draw in soup.find_all('td',attrs = {'data-stat':'draws'})][0:20]

losses = [loss.text for loss in soup.find_all('td',attrs = {'data-stat':'losses'})][0:20]

goals_for = [goal.text for goal in soup.find_all('td',\
                                                    attrs = {'data-stat':'goals_for'})][0:20]

goals_against = [goal.text for goal in soup.find_all\
                                         ('td',attrs = {'data-stat':'goals_against'})][0:20]

points = [point.text for point in soup.find_all('td',attrs = {'data-stat':'points'})][0:20]

x_goals = [goal.text for goal in soup.find_all('td',attrs = {'data-stat':'xg_for'})][0:20]

x_goals_A = [goal.text for goal in soup.find_all\
                                             ('td',attrs = {'data-stat':'xg_against'})][0:20]

attendance = [att.text for att in soup.find_all\
                                    ('td',attrs = {'data-stat':'attendance_per_g'})][0:20]


for num in range(0,16):
    my_dict={'RANK':ranking[num],'TEAM':squad[num], 'W':wins[num], 'D':draws[num],\
             'L':losses[num], 'GF':goals_for[num], 'GA':goals_against[num],\
             'PTS':points[num],'ATT':attendance[num]}
    league_table_16.append(my_dict)
    my_dict = dict()

league_table_16
# Out:
# [{'RANK': '1',
#   'TEAM': 'CSKA Moscow',
#   'W': '20',
#   'D': '5',
#   'L': '5',
#   'GF': '51',
#   'GA': '25',
#   'PTS': '65',
#   'ATT': '9,591'},
#  {'RANK': '2',
#   'TEAM': 'Rostov',
#   'W': '19',
#   'D': '6',
#   'L': '5',
#   'GF': '41',
#   'GA': '20',
#   'PTS': '63',
#   'ATT': '13,334'},
#  {'RANK': '3',
#   'TEAM': 'Zenit',
#   'W': '17',
#   'D': '8',
#   'L': '5',
#   'GF': '61',
#   'GA': '32',
#   'PTS': '59',
#   'ATT': '16,813'},
#  {'RANK': '4',
#   'TEAM': 'Krasnodar',
#   'W': '16',
#   'D': '8',
#   'L': '6',
#   'GF': '54',
#   'GA': '25',
#   'PTS': '56',
#   'ATT': '10,939'},
#  {'RANK': '5',
#   'TEAM': 'Spartak Moscow',
#   'W': '15',
#   'D': '5',
#   'L': '10',
#   'GF': '48',
#   'GA': '39',
#   'PTS': '50',
#   'ATT': '25,179'},
#  {'RANK': '6',
#   'TEAM': 'Loko Moscow',
#   'W': '14',
#   'D': '8',
#   'L': '8',
#   'GF': '43',
#   'GA': '33',
#   'PTS': '50',
#   'ATT': '9,815'},
#  {'RANK': '7',
#   'TEAM': 'Terek Grozny',
#   'W': '11',
# ...

# %%
RPL_16_table_df = pd.DataFrame(league_table_16)
RPL_16_table_df.style.hide_index()
# Out:
# /tmp/ipykernel_16884/3703451301.py:2: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   RPL_16_table_df.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_fcb79">
#   <thead>
#     <tr>
#       <th id="T_fcb79_level0_col0" class="col_heading level0 col0" >RANK</th>
#       <th id="T_fcb79_level0_col1" class="col_heading level0 col1" >TEAM</th>
#       <th id="T_fcb79_level0_col2" class="col_heading level0 col2" >W</th>
#       <th id="T_fcb79_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_fcb79_level0_col4" class="col_heading level0 col4" >L</th>
#       <th id="T_fcb79_level0_col5" class="col_heading level0 col5" >GF</th>
#       <th id="T_fcb79_level0_col6" class="col_heading level0 col6" >GA</th>
#       <th id="T_fcb79_level0_col7" class="col_heading level0 col7" >PTS</th>
#       <th id="T_fcb79_level0_col8" class="col_heading level0 col8" >ATT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
url = 'https://fbref.com/en/comps/30/748/2014-2015-Russian-Premier-League-Stats#results7481_overall'

response = requests.get(url)
status = response.status_code
if status == 200:
  page = response.text
  soup = bs(page)
else:
  print(f"Oops! Received status code {status}")

# %%
league_table_15 = []

ranking= [rank['csk'] for rank in soup.find_all\
                            ('th', attrs={'scope':'row','data-stat':'rank'})][0:20]

squad = [team.text.strip() for team in soup.find_all('td',attrs={'data-stat':'squad'})][0:20]

wins = [win.text for win in soup.find_all('td',attrs = {'data-stat':'wins'})][0:20]

draws = [draw.text for draw in soup.find_all('td',attrs = {'data-stat':'draws'})][0:20]

losses = [loss.text for loss in soup.find_all('td',attrs = {'data-stat':'losses'})][0:20]

goals_for = [goal.text for goal in soup.find_all('td',\
                                                    attrs = {'data-stat':'goals_for'})][0:20]

goals_against = [goal.text for goal in soup.find_all\
                                         ('td',attrs = {'data-stat':'goals_against'})][0:20]

points = [point.text for point in soup.find_all('td',attrs = {'data-stat':'points'})][0:20]

x_goals = [goal.text for goal in soup.find_all('td',attrs = {'data-stat':'xg_for'})][0:20]

x_goals_A = [goal.text for goal in soup.find_all\
                                             ('td',attrs = {'data-stat':'xg_against'})][0:20]

attendance = [att.text for att in soup.find_all\
                                    ('td',attrs = {'data-stat':'attendance_per_g'})][0:20]


for num in range(0,16):
    my_dict={'RANK':ranking[num],'TEAM':squad[num], 'W':wins[num], 'D':draws[num],\
             'L':losses[num], 'GF':goals_for[num], 'GA':goals_against[num],\
             'PTS':points[num],'ATT':attendance[num]}
    league_table_15.append(my_dict)
    my_dict = dict()

league_table_15
# Out:
# [{'RANK': '1',
#   'TEAM': 'Zenit',
#   'W': '20',
#   'D': '7',
#   'L': '3',
#   'GF': '58',
#   'GA': '17',
#   'PTS': '67',
#   'ATT': '14,307'},
#  {'RANK': '2',
#   'TEAM': 'CSKA Moscow',
#   'W': '19',
#   'D': '3',
#   'L': '8',
#   'GF': '67',
#   'GA': '27',
#   'PTS': '60',
#   'ATT': '9,460'},
#  {'RANK': '3',
#   'TEAM': 'Krasnodar',
#   'W': '17',
#   'D': '9',
#   'L': '4',
#   'GF': '52',
#   'GA': '27',
#   'PTS': '60',
#   'ATT': '11,290'},
#  {'RANK': '4',
#   'TEAM': 'Dynamo Mosc',
#   'W': '14',
#   'D': '8',
#   'L': '8',
#   'GF': '53',
#   'GA': '36',
#   'PTS': '50',
#   'ATT': '7,336'},
#  {'RANK': '5',
#   'TEAM': 'Rubin Kazan',
#   'W': '13',
#   'D': '9',
#   'L': '8',
#   'GF': '39',
#   'GA': '33',
#   'PTS': '48',
#   'ATT': '13,550'},
#  {'RANK': '6',
#   'TEAM': 'Spartak Moscow',
#   'W': '12',
#   'D': '8',
#   'L': '10',
#   'GF': '42',
#   'GA': '42',
#   'PTS': '44',
#   'ATT': '25,001'},
#  {'RANK': '7',
#   'TEAM': 'Loko Moscow',
# ...

# %%
RPL_15_table_df = pd.DataFrame(league_table_15)
RPL_15_table_df.style.hide_index()
# Out:
# /tmp/ipykernel_16884/4030382045.py:2: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   RPL_15_table_df.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_a17e4">
#   <thead>
#     <tr>
#       <th id="T_a17e4_level0_col0" class="col_heading level0 col0" >RANK</th>
#       <th id="T_a17e4_level0_col1" class="col_heading level0 col1" >TEAM</th>
#       <th id="T_a17e4_level0_col2" class="col_heading level0 col2" >W</th>
#       <th id="T_a17e4_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_a17e4_level0_col4" class="col_heading level0 col4" >L</th>
#       <th id="T_a17e4_level0_col5" class="col_heading level0 col5" >GF</th>
#       <th id="T_a17e4_level0_col6" class="col_heading level0 col6" >GA</th>
#       <th id="T_a17e4_level0_col7" class="col_heading level0 col7" >PTS</th>
#       <th id="T_a17e4_level0_col8" class="col_heading level0 col8" >ATT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
url = 'https://fbref.com/en/comps/30/748/2014-2015-Russian-Premier-League-Stats#stats_squads_standard_for'

response = requests.get(url)
status = response.status_code
if status == 200:
  page = response.text
  soup = bs(page)
else:
  print(f"Oops! Received status code {status}")

# %%
squad_std_15 = []

squad = [team.text.strip() for team in soup.find_all('th',attrs={'data-stat':'squad'})][3:23]

players = [player.text for player in soup.find_all\
                                           ('td',attrs = {'data-stat':'players_used'})][0:20]

avg_age = [age.text for age in soup.find_all('td',attrs = {'data-stat':'avg_age'})][0:20]

possession = [poss.text for poss in soup.find_all('td',\
                                                  attrs = {'data-stat':'possession'})][0:20]

for num in range(0,16):
    my_dict={'TEAM':squad[num], 'PL':players[num], 'AGE':avg_age[num],\
             'POSS':possession[num]}
    squad_std_15.append(my_dict)
    my_dict = dict()

squad_std_15
# Out:
# [{'TEAM': 'Amkar Perm', 'PL': '34', 'AGE': '27.6', 'POSS': '45.7'},
#  {'TEAM': 'Arsenal Tula', 'PL': '40', 'AGE': '28.6', 'POSS': '47.5'},
#  {'TEAM': 'CSKA Moscow', 'PL': '23', 'AGE': '27.0', 'POSS': '54.8'},
#  {'TEAM': 'Dynamo Mosc', 'PL': '28', 'AGE': '28.0', 'POSS': '53.9'},
#  {'TEAM': 'Krasnodar', 'PL': '22', 'AGE': '28.5', 'POSS': '51.1'},
#  {'TEAM': 'Kuban', 'PL': '24', 'AGE': '27.0', 'POSS': '50.5'},
#  {'TEAM': 'Loko Moscow', 'PL': '25', 'AGE': '28.4', 'POSS': '52.4'},
#  {'TEAM': 'Mordovia', 'PL': '26', 'AGE': '27.4', 'POSS': '47.9'},
#  {'TEAM': 'Rostov', 'PL': '27', 'AGE': '27.8', 'POSS': '48.9'},
#  {'TEAM': 'Rubin Kazan', 'PL': '27', 'AGE': '26.8', 'POSS': '49.9'},
#  {'TEAM': 'Spartak Moscow', 'PL': '33', 'AGE': '26.7', 'POSS': '51.6'},
#  {'TEAM': 'Terek Grozny', 'PL': '24', 'AGE': '27.4', 'POSS': '51.1'},
#  {'TEAM': 'Torpedo Moscow', 'PL': '30', 'AGE': '27.8', 'POSS': '47.8'},
#  {'TEAM': 'Ufa', 'PL': '28', 'AGE': '27.0', 'POSS': '44.5'},
# ...

# %%
RPL_15_squad_df = pd.DataFrame(squad_std_15)
RPL_15_squad_df.style.hide_index()
# Out:
# /tmp/ipykernel_16884/3482186417.py:2: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   RPL_15_squad_df.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_1f419">
#   <thead>
#     <tr>
#       <th id="T_1f419_level0_col0" class="col_heading level0 col0" >TEAM</th>
#       <th id="T_1f419_level0_col1" class="col_heading level0 col1" >PL</th>
#       <th id="T_1f419_level0_col2" class="col_heading level0 col2" >AGE</th>
#       <th id="T_1f419_level0_col3" class="col_heading level0 col3" >POSS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1f419_row0_col0" class="data row0 col0" >Amkar Perm</td>
#       <td id="T_1f419_row0_col1" class="data row0 col1" >34</td>
#       <td id="T_1f419_row0_col2" class="data row0 col2" >27.6</td>
#       <td id="T_1f419_row0_col3" class="data row0 col3" >45.7</td>
#     </tr>
#     <tr>
#       <td id="T_1f419_row1_col0" class="data row1 col0" >Arsenal Tula</td>
# ...

# %%
url = 'https://fbref.com/en/comps/30/1482/2015-2016-Russian-Premier-League-Stats#stats_squads_standard_for'

response = requests.get(url)
status = response.status_code
if status == 200:
  page = response.text
  soup = bs(page)
else:
  print(f"Oops! Received status code {status}")

# %%
squad_std_16 = []

squad = [team.text.strip() for team in soup.find_all('th',attrs={'data-stat':'squad'})][3:23]

players = [player.text for player in soup.find_all\
                                           ('td',attrs = {'data-stat':'players_used'})][0:20]

avg_age = [age.text for age in soup.find_all('td',attrs = {'data-stat':'avg_age'})][0:20]

possession = [poss.text for poss in soup.find_all('td',\
                                                  attrs = {'data-stat':'possession'})][0:20]

for num in range(0,16):
    my_dict={'TEAM':squad[num], 'PL':players[num], 'AGE':avg_age[num],\
             'POSS':possession[num]}
    squad_std_16.append(my_dict)
    my_dict = dict()

squad_std_16
# Out:
# [{'TEAM': 'Amkar Perm', 'PL': '27', 'AGE': '27.0', 'POSS': '45.0'},
#  {'TEAM': 'Anzhi', 'PL': '29', 'AGE': '25.5', 'POSS': '44.7'},
#  {'TEAM': 'CSKA Moscow', 'PL': '24', 'AGE': '27.8', 'POSS': '59.2'},
#  {'TEAM': 'Dynamo Mosc', 'PL': '34', 'AGE': '26.6', 'POSS': '50.7'},
#  {'TEAM': 'Krasnodar', 'PL': '24', 'AGE': '28.3', 'POSS': '58.8'},
#  {'TEAM': 'Kuban', 'PL': '31', 'AGE': '27.2', 'POSS': '44.1'},
#  {'TEAM': 'Loko Moscow', 'PL': '26', 'AGE': '28.0', 'POSS': '52.5'},
#  {'TEAM': 'Mordovia', 'PL': '28', 'AGE': '28.7', 'POSS': '45.3'},
#  {'TEAM': 'Rostov', 'PL': '23', 'AGE': '27.2', 'POSS': '47.4'},
#  {'TEAM': 'Rubin Kazan', 'PL': '28', 'AGE': '27.0', 'POSS': '50.5'},
#  {'TEAM': 'Samara', 'PL': '25', 'AGE': '27.1', 'POSS': '43.4'},
#  {'TEAM': 'Spartak Moscow', 'PL': '30', 'AGE': '27.0', 'POSS': '55.4'},
#  {'TEAM': 'Terek Grozny', 'PL': '26', 'AGE': '27.5', 'POSS': '56.3'},
#  {'TEAM': 'Ufa', 'PL': '29', 'AGE': '26.5', 'POSS': '38.0'},
# ...

# %%
RPL_16_squad_df = pd.DataFrame(squad_std_16)
RPL_16_squad_df.style.hide_index()
# Out:
# /tmp/ipykernel_16884/2765428781.py:2: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   RPL_16_squad_df.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_9c8e9">
#   <thead>
#     <tr>
#       <th id="T_9c8e9_level0_col0" class="col_heading level0 col0" >TEAM</th>
#       <th id="T_9c8e9_level0_col1" class="col_heading level0 col1" >PL</th>
#       <th id="T_9c8e9_level0_col2" class="col_heading level0 col2" >AGE</th>
#       <th id="T_9c8e9_level0_col3" class="col_heading level0 col3" >POSS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9c8e9_row0_col0" class="data row0 col0" >Amkar Perm</td>
#       <td id="T_9c8e9_row0_col1" class="data row0 col1" >27</td>
#       <td id="T_9c8e9_row0_col2" class="data row0 col2" >27.0</td>
#       <td id="T_9c8e9_row0_col3" class="data row0 col3" >45.0</td>
#     </tr>
#     <tr>
#       <td id="T_9c8e9_row1_col0" class="data row1 col0" >Anzhi</td>
# ...

# %%
url = 'https://fbref.com/en/comps/30/1541/2016-2017-Russian-Premier-League-Stats#stats_squads_standard_for'

response = requests.get(url)
status = response.status_code
if status == 200:
  page = response.text
  soup = bs(page)
else:
  print(f"Oops! Received status code {status}")

# %%
squad_std_17 = []

squad = [team.text.strip() for team in soup.find_all('th',attrs={'data-stat':'squad'})][3:23]

players = [player.text for player in soup.find_all\
                                           ('td',attrs = {'data-stat':'players_used'})][0:20]

avg_age = [age.text for age in soup.find_all('td',attrs = {'data-stat':'avg_age'})][0:20]

possession = [poss.text for poss in soup.find_all('td',\
                                                  attrs = {'data-stat':'possession'})][0:20]

for num in range(0,16):
    my_dict={'TEAM':squad[num], 'PL':players[num], 'AGE':avg_age[num],\
             'POSS':possession[num]}
    squad_std_17.append(my_dict)
    my_dict = dict()

squad_std_17
# Out:
# [{'TEAM': 'Amkar Perm', 'PL': '24', 'AGE': '26.8', 'POSS': '46.4'},
#  {'TEAM': 'Anzhi', 'PL': '39', 'AGE': '25.7', 'POSS': '45.7'},
#  {'TEAM': 'Arsenal Tula', 'PL': '38', 'AGE': '28.3', 'POSS': '44.5'},
#  {'TEAM': 'CSKA Moscow', 'PL': '25', 'AGE': '28.0', 'POSS': '56.8'},
#  {'TEAM': 'Krasnodar', 'PL': '30', 'AGE': '27.9', 'POSS': '60.7'},
#  {'TEAM': 'Loko Moscow', 'PL': '30', 'AGE': '28.8', 'POSS': '54.7'},
#  {'TEAM': 'Orenburg', 'PL': '34', 'AGE': '29.2', 'POSS': '41.7'},
#  {'TEAM': 'Rostov', 'PL': '30', 'AGE': '28.2', 'POSS': '48.0'},
#  {'TEAM': 'Rubin Kazan', 'PL': '28', 'AGE': '26.7', 'POSS': '51.9'},
#  {'TEAM': 'Samara', 'PL': '31', 'AGE': '27.4', 'POSS': '48.3'},
#  {'TEAM': 'Spartak Moscow', 'PL': '29', 'AGE': '27.2', 'POSS': '58.3'},
#  {'TEAM': 'Terek Grozny', 'PL': '27', 'AGE': '26.5', 'POSS': '48.7'},
#  {'TEAM': 'Tom Tomsk', 'PL': '37', 'AGE': '25.7', 'POSS': '42.5'},
#  {'TEAM': 'Ufa', 'PL': '29', 'AGE': '26.4', 'POSS': '45.1'},
# ...

# %%
RPL_17_squad_df = pd.DataFrame(squad_std_17)
RPL_17_squad_df.style.hide_index()
# Out:
# /tmp/ipykernel_16884/360904997.py:2: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   RPL_17_squad_df.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_7ce8b">
#   <thead>
#     <tr>
#       <th id="T_7ce8b_level0_col0" class="col_heading level0 col0" >TEAM</th>
#       <th id="T_7ce8b_level0_col1" class="col_heading level0 col1" >PL</th>
#       <th id="T_7ce8b_level0_col2" class="col_heading level0 col2" >AGE</th>
#       <th id="T_7ce8b_level0_col3" class="col_heading level0 col3" >POSS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7ce8b_row0_col0" class="data row0 col0" >Amkar Perm</td>
#       <td id="T_7ce8b_row0_col1" class="data row0 col1" >24</td>
#       <td id="T_7ce8b_row0_col2" class="data row0 col2" >26.8</td>
#       <td id="T_7ce8b_row0_col3" class="data row0 col3" >46.4</td>
#     </tr>
#     <tr>
#       <td id="T_7ce8b_row1_col0" class="data row1 col0" >Anzhi</td>
# ...

# %%
url = 'https://fbref.com/en/comps/30/1646/2017-2018-Russian-Premier-League-Stats#stats_squads_standard_for'

response = requests.get(url)
status = response.status_code
if status == 200:
  page = response.text
  soup = bs(page)
else:
  print(f"Oops! Received status code {status}")

# %%
squad_std_18 = []

squad = [team.text.strip() for team in soup.find_all('th',attrs={'data-stat':'squad'})][3:23]

players = [player.text for player in soup.find_all\
                                           ('td',attrs = {'data-stat':'players_used'})][0:20]

avg_age = [age.text for age in soup.find_all('td',attrs = {'data-stat':'avg_age'})][0:20]

possession = [poss.text for poss in soup.find_all('td',\
                                                  attrs = {'data-stat':'possession'})][0:20]

for num in range(0,16):
    my_dict={'TEAM':squad[num], 'PL':players[num], 'AGE':avg_age[num],\
             'POSS':possession[num]}
    squad_std_18.append(my_dict)
    my_dict = dict()

squad_std_18
# Out:
# [{'TEAM': 'Akhmat Grozny', 'PL': '24', 'AGE': '26.2', 'POSS': '47.5'},
#  {'TEAM': 'Amkar Perm', 'PL': '26', 'AGE': '28.0', 'POSS': '41.5'},
#  {'TEAM': 'Anzhi', 'PL': '36', 'AGE': '27.5', 'POSS': '46.3'},
#  {'TEAM': 'Arsenal Tula', 'PL': '27', 'AGE': '28.0', 'POSS': '48.5'},
#  {'TEAM': 'CSKA Moscow', 'PL': '24', 'AGE': '28.3', 'POSS': '56.9'},
#  {'TEAM': 'Dynamo Mosc', 'PL': '29', 'AGE': '27.6', 'POSS': '46.9'},
#  {'TEAM': 'Krasnodar', 'PL': '28', 'AGE': '27.4', 'POSS': '59.4'},
#  {'TEAM': 'Loko Moscow', 'PL': '24', 'AGE': '28.5', 'POSS': '53.6'},
#  {'TEAM': 'Rostov', 'PL': '29', 'AGE': '28.0', 'POSS': '47.5'},
#  {'TEAM': 'Rubin Kazan', 'PL': '33', 'AGE': '28.3', 'POSS': '52.1'},
#  {'TEAM': 'SKA-Khabarovsk', 'PL': '37', 'AGE': '28.3', 'POSS': '41.9'},
#  {'TEAM': 'Spartak Moscow', 'PL': '28', 'AGE': '27.6', 'POSS': '57.1'},
#  {'TEAM': 'Tosno', 'PL': '34', 'AGE': '26.6', 'POSS': '44.5'},
#  {'TEAM': 'Ufa', 'PL': '25', 'AGE': '27.5', 'POSS': '47.0'},
# ...

# %%
RPL_18_squad_df = pd.DataFrame(squad_std_18)
RPL_18_squad_df.style.hide_index()
# Out:
# /tmp/ipykernel_16884/3228214610.py:2: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   RPL_18_squad_df.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_47362">
#   <thead>
#     <tr>
#       <th id="T_47362_level0_col0" class="col_heading level0 col0" >TEAM</th>
#       <th id="T_47362_level0_col1" class="col_heading level0 col1" >PL</th>
#       <th id="T_47362_level0_col2" class="col_heading level0 col2" >AGE</th>
#       <th id="T_47362_level0_col3" class="col_heading level0 col3" >POSS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_47362_row0_col0" class="data row0 col0" >Akhmat Grozny</td>
#       <td id="T_47362_row0_col1" class="data row0 col1" >24</td>
#       <td id="T_47362_row0_col2" class="data row0 col2" >26.2</td>
#       <td id="T_47362_row0_col3" class="data row0 col3" >47.5</td>
#     </tr>
#     <tr>
#       <td id="T_47362_row1_col0" class="data row1 col0" >Amkar Perm</td>
# ...

# %%
url = 'https://fbref.com/en/comps/30/2371/2018-2019-Russian-Premier-League-Stats#stats_squads_standard_for'

response = requests.get(url)
status = response.status_code
if status == 200:
  page = response.text
  soup = bs(page)
else:
  print(f"Oops! Received status code {status}")

# %%
squad_std_19 = []

squad = [team.text.strip() for team in soup.find_all('th',attrs={'data-stat':'squad'})][3:23]

players = [player.text for player in soup.find_all\
                                           ('td',attrs = {'data-stat':'players_used'})][0:20]

avg_age = [age.text for age in soup.find_all('td',attrs = {'data-stat':'avg_age'})][0:20]

possession = [poss.text for poss in soup.find_all('td',\
                                                  attrs = {'data-stat':'possession'})][0:20]

for num in range(0,16):
    my_dict={'TEAM':squad[num], 'PL':players[num], 'AGE':avg_age[num],\
             'POSS':possession[num]}
    squad_std_19.append(my_dict)
    my_dict = dict()

squad_std_19
# Out:
# [{'TEAM': 'Akhmat Grozny', 'PL': '25', 'AGE': '27.2', 'POSS': '48.1'},
#  {'TEAM': 'Anzhi', 'PL': '34', 'AGE': '26.7', 'POSS': '40.7'},
#  {'TEAM': 'Arsenal Tula', 'PL': '25', 'AGE': '27.0', 'POSS': '48.3'},
#  {'TEAM': 'CSKA Moscow', 'PL': '24', 'AGE': '24.1', 'POSS': '54.1'},
#  {'TEAM': 'Dynamo Mosc', 'PL': '23', 'AGE': '28.0', 'POSS': '49.9'},
#  {'TEAM': 'Krasnodar', 'PL': '28', 'AGE': '26.9', 'POSS': '60.9'},
#  {'TEAM': 'Loko Moscow', 'PL': '24', 'AGE': '28.5', 'POSS': '53.8'},
#  {'TEAM': 'Orenburg', 'PL': '23', 'AGE': '28.6', 'POSS': '43.2'},
#  {'TEAM': 'Rostov', 'PL': '30', 'AGE': '27.8', 'POSS': '48.3'},
#  {'TEAM': 'Rubin Kazan', 'PL': '27', 'AGE': '26.4', 'POSS': '50.5'},
#  {'TEAM': 'Samara', 'PL': '33', 'AGE': '28.6', 'POSS': '49.3'},
#  {'TEAM': 'Spartak Moscow', 'PL': '36', 'AGE': '26.1', 'POSS': '56.6'},
#  {'TEAM': 'Ufa', 'PL': '29', 'AGE': '27.2', 'POSS': '45.3'},
#  {'TEAM': 'Ural', 'PL': '27', 'AGE': '28.5', 'POSS': '50.5'},
# ...

# %%
RPL_19_squad_df = pd.DataFrame(squad_std_19)
RPL_19_squad_df.style.hide_index()
# Out:
# /tmp/ipykernel_16884/1753142090.py:2: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   RPL_19_squad_df.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_31db1">
#   <thead>
#     <tr>
#       <th id="T_31db1_level0_col0" class="col_heading level0 col0" >TEAM</th>
#       <th id="T_31db1_level0_col1" class="col_heading level0 col1" >PL</th>
#       <th id="T_31db1_level0_col2" class="col_heading level0 col2" >AGE</th>
#       <th id="T_31db1_level0_col3" class="col_heading level0 col3" >POSS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_31db1_row0_col0" class="data row0 col0" >Akhmat Grozny</td>
#       <td id="T_31db1_row0_col1" class="data row0 col1" >25</td>
#       <td id="T_31db1_row0_col2" class="data row0 col2" >27.2</td>
#       <td id="T_31db1_row0_col3" class="data row0 col3" >48.1</td>
#     </tr>
#     <tr>
#       <td id="T_31db1_row1_col0" class="data row1 col0" >Anzhi</td>
# ...

# %%
url = 'https://fbref.com/en/comps/30/3285/2019-2020-Russian-Premier-League-Stats#stats_squads_standard_for'
response = requests.get(url)
status = response.status_code
if status == 200:
  page = response.text
  soup = bs(page)
else:
  print(f"Oops! Received status code {status}")

# %%
squad_std_20 = []

squad = [team.text.strip() for team in soup.find_all('th',attrs={'data-stat':'squad'})][3:23]

players = [player.text for player in soup.find_all\
                                           ('td',attrs = {'data-stat':'players_used'})][0:20]

avg_age = [age.text for age in soup.find_all('td',attrs = {'data-stat':'avg_age'})][0:20]

possession = [poss.text for poss in soup.find_all('td',\
                                                  attrs = {'data-stat':'possession'})][0:20]

for num in range(0,16):
    my_dict={'TEAM':squad[num], 'PL':players[num], 'AGE':avg_age[num],\
             'POSS':possession[num]}
    squad_std_20.append(my_dict)
    my_dict = dict()

squad_std_20
# Out:
# [{'TEAM': 'Akhmat Grozny', 'PL': '30', 'AGE': '27.9', 'POSS': '50.4'},
#  {'TEAM': 'Arsenal Tula', 'PL': '32', 'AGE': '27.5', 'POSS': '49.1'},
#  {'TEAM': 'CSKA Moscow', 'PL': '25', 'AGE': '24.1', 'POSS': '54.6'},
#  {'TEAM': 'Dynamo Mosc', 'PL': '31', 'AGE': '27.7', 'POSS': '50.9'},
#  {'TEAM': 'Krasnodar', 'PL': '31', 'AGE': '26.4', 'POSS': '60.4'},
#  {'TEAM': 'Loko Moscow', 'PL': '28', 'AGE': '27.9', 'POSS': '53.6'},
#  {'TEAM': 'Orenburg', 'PL': '32', 'AGE': '27.5', 'POSS': '44.4'},
#  {'TEAM': 'Rostov', 'PL': '42', 'AGE': '26.8', 'POSS': '50.8'},
#  {'TEAM': 'Rubin Kazan', 'PL': '32', 'AGE': '24.3', 'POSS': '52.1'},
#  {'TEAM': 'Samara', 'PL': '30', 'AGE': '28.3', 'POSS': '46.0'},
#  {'TEAM': 'Sochi', 'PL': '31', 'AGE': '27.9', 'POSS': '44.4'},
#  {'TEAM': 'Spartak Moscow', 'PL': '34', 'AGE': '23.7', 'POSS': '53.6'},
#  {'TEAM': 'Tambov', 'PL': '34', 'AGE': '28.2', 'POSS': '41.9'},
#  {'TEAM': 'Ufa', 'PL': '30', 'AGE': '26.2', 'POSS': '41.3'},
# ...

# %%
RPL_20_squad_df = pd.DataFrame(squad_std_20)
RPL_20_squad_df.style.hide_index()
# Out:
# /tmp/ipykernel_16884/3993434374.py:2: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   RPL_20_squad_df.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_b7be9">
#   <thead>
#     <tr>
#       <th id="T_b7be9_level0_col0" class="col_heading level0 col0" >TEAM</th>
#       <th id="T_b7be9_level0_col1" class="col_heading level0 col1" >PL</th>
#       <th id="T_b7be9_level0_col2" class="col_heading level0 col2" >AGE</th>
#       <th id="T_b7be9_level0_col3" class="col_heading level0 col3" >POSS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b7be9_row0_col0" class="data row0 col0" >Akhmat Grozny</td>
#       <td id="T_b7be9_row0_col1" class="data row0 col1" >30</td>
#       <td id="T_b7be9_row0_col2" class="data row0 col2" >27.9</td>
#       <td id="T_b7be9_row0_col3" class="data row0 col3" >50.4</td>
#     </tr>
#     <tr>
#       <td id="T_b7be9_row1_col0" class="data row1 col0" >Arsenal Tula</td>
# ...

# %%
url = 'https://fbref.com/en/comps/30/10742/2020-2021-Russian-Premier-League-Stats#stats_squads_standard_for'
response = requests.get(url)
status = response.status_code
if status == 200:
  page = response.text
  soup = bs(page)
else:
  print(f"Oops! Received status code {status}")

# %%
squad_std_21 = []

squad = [team.text.strip() for team in soup.find_all('th',attrs={'data-stat':'squad'})][3:23]

players = [player.text for player in soup.find_all\
                                           ('td',attrs = {'data-stat':'players_used'})][0:20]

avg_age = [age.text for age in soup.find_all('td',attrs = {'data-stat':'avg_age'})][0:20]

possession = [poss.text for poss in soup.find_all('td',\
                                                  attrs = {'data-stat':'possession'})][0:20]

for num in range(0,16):
    my_dict={'TEAM':squad[num], 'PL':players[num], 'AGE':avg_age[num],\
             'POSS':possession[num]}
    squad_std_21.append(my_dict)
    my_dict = dict()

squad_std_21
# Out:
# [{'TEAM': 'Akhmat Grozny', 'PL': '32', 'AGE': '26.7', 'POSS': '48.3'},
#  {'TEAM': 'Arsenal Tula', 'PL': '34', 'AGE': '26.8', 'POSS': '49.3'},
#  {'TEAM': 'CSKA Moscow', 'PL': '28', 'AGE': '25.0', 'POSS': '54.0'},
#  {'TEAM': 'Dynamo Mosc', 'PL': '30', 'AGE': '25.5', 'POSS': '52.0'},
#  {'TEAM': 'FC Khimki', 'PL': '33', 'AGE': '25.8', 'POSS': '43.8'},
#  {'TEAM': 'Krasnodar', 'PL': '32', 'AGE': '27.6', 'POSS': '60.8'},
#  {'TEAM': 'Loko Moscow', 'PL': '29', 'AGE': '27.5', 'POSS': '54.8'},
#  {'TEAM': 'Rostov', 'PL': '40', 'AGE': '26.4', 'POSS': '50.8'},
#  {'TEAM': 'Rotor Volgograd', 'PL': '32', 'AGE': '26.0', 'POSS': '43.2'},
#  {'TEAM': 'Rubin Kazan', 'PL': '26', 'AGE': '25.5', 'POSS': '48.5'},
#  {'TEAM': 'Sochi', 'PL': '29', 'AGE': '29.2', 'POSS': '46.5'},
#  {'TEAM': 'Spartak Moscow', 'PL': '28', 'AGE': '24.3', 'POSS': '58.4'},
#  {'TEAM': 'Tambov', 'PL': '50', 'AGE': '28.1', 'POSS': '37.7'},
#  {'TEAM': 'Ufa', 'PL': '36', 'AGE': '27.5', 'POSS': '43.8'},
# ...

# %%
RPL_21_squad_df = pd.DataFrame(squad_std_21)
RPL_21_squad_df.style.hide_index()
# Out:
# /tmp/ipykernel_16884/604825284.py:2: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   RPL_21_squad_df.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_4f4d9">
#   <thead>
#     <tr>
#       <th id="T_4f4d9_level0_col0" class="col_heading level0 col0" >TEAM</th>
#       <th id="T_4f4d9_level0_col1" class="col_heading level0 col1" >PL</th>
#       <th id="T_4f4d9_level0_col2" class="col_heading level0 col2" >AGE</th>
#       <th id="T_4f4d9_level0_col3" class="col_heading level0 col3" >POSS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4f4d9_row0_col0" class="data row0 col0" >Akhmat Grozny</td>
#       <td id="T_4f4d9_row0_col1" class="data row0 col1" >32</td>
#       <td id="T_4f4d9_row0_col2" class="data row0 col2" >26.7</td>
#       <td id="T_4f4d9_row0_col3" class="data row0 col3" >48.3</td>
#     </tr>
#     <tr>
#       <td id="T_4f4d9_row1_col0" class="data row1 col0" >Arsenal Tula</td>
# ...

# %%
url = 'https://fbref.com/en/comps/30/Russian-Premier-League-Stats#stats_squads_standard_for'
response = requests.get(url)
status = response.status_code
if status == 200:
  page = response.text
  soup = bs(page)
else:
  print(f"Oops! Received status code {status}")

# %%
squad_std_22 = []

squad = [team.text.strip() for team in soup.find_all('th',attrs={'data-stat':'squad'})][3:23]

players = [player.text for player in soup.find_all\
                                           ('td',attrs = {'data-stat':'players_used'})][0:20]

avg_age = [age.text for age in soup.find_all('td',attrs = {'data-stat':'avg_age'})][0:20]

possession = [poss.text for poss in soup.find_all('td',\
                                                  attrs = {'data-stat':'possession'})][0:20]

for num in range(0,16):
    my_dict={'TEAM':squad[num], 'PL':players[num], 'AGE':avg_age[num],\
             'POSS':possession[num]}
    squad_std_22.append(my_dict)
    my_dict = dict()

squad_std_22
# Out:
# [{'TEAM': 'Akhmat Grozny', 'PL': '30', 'AGE': '26.9', 'POSS': '46.4'},
#  {'TEAM': 'Arsenal Tula', 'PL': '31', 'AGE': '27.5', 'POSS': '44.7'},
#  {'TEAM': 'CSKA Moscow', 'PL': '32', 'AGE': '25.9', 'POSS': '55.7'},
#  {'TEAM': 'Dynamo Mosc', 'PL': '25', 'AGE': '25.5', 'POSS': '50.5'},
#  {'TEAM': 'FC Khimki', 'PL': '35', 'AGE': '26.5', 'POSS': '46.0'},
#  {'TEAM': 'Krasnodar', 'PL': '45', 'AGE': '25.8', 'POSS': '57.0'},
#  {'TEAM': 'Loko Moscow', 'PL': '34', 'AGE': '24.8', 'POSS': '53.1'},
#  {'TEAM': 'Nizhny Novgorod', 'PL': '33', 'AGE': '26.6', 'POSS': '40.8'},
#  {'TEAM': 'Rostov', 'PL': '33', 'AGE': '25.4', 'POSS': '50.4'},
#  {'TEAM': 'Rubin Kazan', 'PL': '34', 'AGE': '25.6', 'POSS': '46.4'},
#  {'TEAM': 'Samara', 'PL': '29', 'AGE': '24.3', 'POSS': '51.6'},
#  {'TEAM': 'Sochi', 'PL': '26', 'AGE': '28.6', 'POSS': '53.8'},
#  {'TEAM': 'Spartak Moscow', 'PL': '34', 'AGE': '25.3', 'POSS': '53.9'},
#  {'TEAM': 'Ufa', 'PL': '28', 'AGE': '27.2', 'POSS': '44.0'},
# ...

# %%
RPL_22_squad_df = pd.DataFrame(squad_std_22)
RPL_22_squad_df.style.hide_index()
# Out:
# /tmp/ipykernel_16884/2114847691.py:2: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   RPL_22_squad_df.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_b6e0a">
#   <thead>
#     <tr>
#       <th id="T_b6e0a_level0_col0" class="col_heading level0 col0" >TEAM</th>
#       <th id="T_b6e0a_level0_col1" class="col_heading level0 col1" >PL</th>
#       <th id="T_b6e0a_level0_col2" class="col_heading level0 col2" >AGE</th>
#       <th id="T_b6e0a_level0_col3" class="col_heading level0 col3" >POSS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b6e0a_row0_col0" class="data row0 col0" >Akhmat Grozny</td>
#       <td id="T_b6e0a_row0_col1" class="data row0 col1" >30</td>
#       <td id="T_b6e0a_row0_col2" class="data row0 col2" >26.9</td>
#       <td id="T_b6e0a_row0_col3" class="data row0 col3" >46.4</td>
#     </tr>
#     <tr>
#       <td id="T_b6e0a_row1_col0" class="data row1 col0" >Arsenal Tula</td>
# ...

# %%
RPL_22 = pd.merge(RPL_22_table_df.sort_values("TEAM"),RPL_22_squad_df, on = "TEAM")
RPL_22["SEASON"]=2022
RPL_22.style.hide_index()
# Out:
# /tmp/ipykernel_16884/1949675022.py:3: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   RPL_22.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_b0c4d">
#   <thead>
#     <tr>
#       <th id="T_b0c4d_level0_col0" class="col_heading level0 col0" >RANK</th>
#       <th id="T_b0c4d_level0_col1" class="col_heading level0 col1" >TEAM</th>
#       <th id="T_b0c4d_level0_col2" class="col_heading level0 col2" >W</th>
#       <th id="T_b0c4d_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_b0c4d_level0_col4" class="col_heading level0 col4" >L</th>
#       <th id="T_b0c4d_level0_col5" class="col_heading level0 col5" >GF</th>
#       <th id="T_b0c4d_level0_col6" class="col_heading level0 col6" >GA</th>
#       <th id="T_b0c4d_level0_col7" class="col_heading level0 col7" >PTS</th>
#       <th id="T_b0c4d_level0_col8" class="col_heading level0 col8" >ATT</th>
# ...

# %%
RPL_21 = pd.merge(RPL_21_table_df.sort_values("TEAM"),RPL_21_squad_df, on = "TEAM")
RPL_21["SEASON"]=2021
RPL_21.style.hide_index()
# Out:
# /tmp/ipykernel_16884/343105368.py:3: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   RPL_21.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_c235b">
#   <thead>
#     <tr>
#       <th id="T_c235b_level0_col0" class="col_heading level0 col0" >RANK</th>
#       <th id="T_c235b_level0_col1" class="col_heading level0 col1" >TEAM</th>
#       <th id="T_c235b_level0_col2" class="col_heading level0 col2" >W</th>
#       <th id="T_c235b_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_c235b_level0_col4" class="col_heading level0 col4" >L</th>
#       <th id="T_c235b_level0_col5" class="col_heading level0 col5" >GF</th>
#       <th id="T_c235b_level0_col6" class="col_heading level0 col6" >GA</th>
#       <th id="T_c235b_level0_col7" class="col_heading level0 col7" >PTS</th>
#       <th id="T_c235b_level0_col8" class="col_heading level0 col8" >ATT</th>
# ...

# %%
RPL_20 = pd.merge(RPL_20_table_df.sort_values("TEAM"),RPL_20_squad_df, on = "TEAM")
RPL_20["SEASON"]=2020
RPL_20.style.hide_index()
# Out:
# /tmp/ipykernel_16884/3205481140.py:3: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   RPL_20.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_8d9a8">
#   <thead>
#     <tr>
#       <th id="T_8d9a8_level0_col0" class="col_heading level0 col0" >RANK</th>
#       <th id="T_8d9a8_level0_col1" class="col_heading level0 col1" >TEAM</th>
#       <th id="T_8d9a8_level0_col2" class="col_heading level0 col2" >W</th>
#       <th id="T_8d9a8_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_8d9a8_level0_col4" class="col_heading level0 col4" >L</th>
#       <th id="T_8d9a8_level0_col5" class="col_heading level0 col5" >GF</th>
#       <th id="T_8d9a8_level0_col6" class="col_heading level0 col6" >GA</th>
#       <th id="T_8d9a8_level0_col7" class="col_heading level0 col7" >PTS</th>
#       <th id="T_8d9a8_level0_col8" class="col_heading level0 col8" >ATT</th>
# ...

# %%
RPL_19 = pd.merge(RPL_19_table_df.sort_values("TEAM"),RPL_19_squad_df, on = "TEAM")
RPL_19["SEASON"]=2019
RPL_19.style.hide_index()
# Out:
# /tmp/ipykernel_16884/1285944865.py:3: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   RPL_19.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_b3a75">
#   <thead>
#     <tr>
#       <th id="T_b3a75_level0_col0" class="col_heading level0 col0" >RANK</th>
#       <th id="T_b3a75_level0_col1" class="col_heading level0 col1" >TEAM</th>
#       <th id="T_b3a75_level0_col2" class="col_heading level0 col2" >W</th>
#       <th id="T_b3a75_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_b3a75_level0_col4" class="col_heading level0 col4" >L</th>
#       <th id="T_b3a75_level0_col5" class="col_heading level0 col5" >GF</th>
#       <th id="T_b3a75_level0_col6" class="col_heading level0 col6" >GA</th>
#       <th id="T_b3a75_level0_col7" class="col_heading level0 col7" >PTS</th>
#       <th id="T_b3a75_level0_col8" class="col_heading level0 col8" >ATT</th>
# ...

# %%
RPL_18 = pd.merge(RPL_18_table_df.sort_values("TEAM"),RPL_18_squad_df, on = "TEAM")
RPL_18["SEASON"]=2018
RPL_18.style.hide_index()
# Out:
# /tmp/ipykernel_16884/426675152.py:3: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   RPL_18.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_3ed17">
#   <thead>
#     <tr>
#       <th id="T_3ed17_level0_col0" class="col_heading level0 col0" >RANK</th>
#       <th id="T_3ed17_level0_col1" class="col_heading level0 col1" >TEAM</th>
#       <th id="T_3ed17_level0_col2" class="col_heading level0 col2" >W</th>
#       <th id="T_3ed17_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_3ed17_level0_col4" class="col_heading level0 col4" >L</th>
#       <th id="T_3ed17_level0_col5" class="col_heading level0 col5" >GF</th>
#       <th id="T_3ed17_level0_col6" class="col_heading level0 col6" >GA</th>
#       <th id="T_3ed17_level0_col7" class="col_heading level0 col7" >PTS</th>
#       <th id="T_3ed17_level0_col8" class="col_heading level0 col8" >ATT</th>
# ...

# %%
RPL_17 = pd.merge(RPL_17_table_df.sort_values("TEAM"),RPL_17_squad_df, on = "TEAM")
RPL_17["SEASON"]=2017
RPL_17.style.hide_index()
# Out:
# /tmp/ipykernel_16884/3240992904.py:3: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   RPL_17.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_faaf2">
#   <thead>
#     <tr>
#       <th id="T_faaf2_level0_col0" class="col_heading level0 col0" >RANK</th>
#       <th id="T_faaf2_level0_col1" class="col_heading level0 col1" >TEAM</th>
#       <th id="T_faaf2_level0_col2" class="col_heading level0 col2" >W</th>
#       <th id="T_faaf2_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_faaf2_level0_col4" class="col_heading level0 col4" >L</th>
#       <th id="T_faaf2_level0_col5" class="col_heading level0 col5" >GF</th>
#       <th id="T_faaf2_level0_col6" class="col_heading level0 col6" >GA</th>
#       <th id="T_faaf2_level0_col7" class="col_heading level0 col7" >PTS</th>
#       <th id="T_faaf2_level0_col8" class="col_heading level0 col8" >ATT</th>
# ...

# %%
RPL_16 = pd.merge(RPL_16_table_df.sort_values("TEAM"),RPL_16_squad_df, on = "TEAM")
RPL_16["SEASON"]=2016
RPL_16.style.hide_index()
# Out:
# /tmp/ipykernel_16884/1971775270.py:3: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   RPL_16.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_b0aed">
#   <thead>
#     <tr>
#       <th id="T_b0aed_level0_col0" class="col_heading level0 col0" >RANK</th>
#       <th id="T_b0aed_level0_col1" class="col_heading level0 col1" >TEAM</th>
#       <th id="T_b0aed_level0_col2" class="col_heading level0 col2" >W</th>
#       <th id="T_b0aed_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_b0aed_level0_col4" class="col_heading level0 col4" >L</th>
#       <th id="T_b0aed_level0_col5" class="col_heading level0 col5" >GF</th>
#       <th id="T_b0aed_level0_col6" class="col_heading level0 col6" >GA</th>
#       <th id="T_b0aed_level0_col7" class="col_heading level0 col7" >PTS</th>
#       <th id="T_b0aed_level0_col8" class="col_heading level0 col8" >ATT</th>
# ...

# %%
RPL_15 = pd.merge(RPL_15_table_df.sort_values("TEAM"),RPL_15_squad_df, on = "TEAM")
RPL_15["SEASON"]=2015
RPL_15.style.hide_index()
# Out:
# /tmp/ipykernel_16884/1839784830.py:3: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   RPL_15.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_dcf07">
#   <thead>
#     <tr>
#       <th id="T_dcf07_level0_col0" class="col_heading level0 col0" >RANK</th>
#       <th id="T_dcf07_level0_col1" class="col_heading level0 col1" >TEAM</th>
#       <th id="T_dcf07_level0_col2" class="col_heading level0 col2" >W</th>
#       <th id="T_dcf07_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_dcf07_level0_col4" class="col_heading level0 col4" >L</th>
#       <th id="T_dcf07_level0_col5" class="col_heading level0 col5" >GF</th>
#       <th id="T_dcf07_level0_col6" class="col_heading level0 col6" >GA</th>
#       <th id="T_dcf07_level0_col7" class="col_heading level0 col7" >PTS</th>
#       <th id="T_dcf07_level0_col8" class="col_heading level0 col8" >ATT</th>
# ...

# %%
RPL_Joint = pd.concat([RPL_22,RPL_21, RPL_20, RPL_19, RPL_18, RPL_17, RPL_16, RPL_15], ignore_index= True)
RPL_Joint.head()
# Out:
#   RANK           TEAM   W   D   L  GF  GA PTS     ATT  PL   AGE  POSS  SEASON
# 0    7  Akhmat Grozny  13   3  14  36  38  42   6,780  30  26.9  46.4    2022
# 1   16   Arsenal Tula   5   8  17  30  59  23   3,237  31  27.5  44.7    2022
# 2    5    CSKA Moscow  15   5  10  42  29  50   7,236  32  25.9  55.7    2022
# 3    3    Dynamo Mosc  16   5   9  53  41  53  10,554  25  25.5  50.5    2022
# 4   13      FC Khimki   7  11  12  34  47  32   1,525  35  26.5  46.0    2022

# %%
RPL_Joint.tail()
# Out:
#     RANK            TEAM   W   D   L  GF  GA PTS     ATT  PL   AGE  POSS  \
# 123    9    Terek Grozny  10   7  13  30  30  37  15,626  24  27.4  51.1
# 124   15  Torpedo Moscow   6  11  13  28  45  29   3,754  30  27.8  47.8
# 125   12             Ufa   7  10  13  26  39  31   3,173  28  27.0  44.5
# 126   13            Ural   9   3  18  31  44  30   7,744  28  26.7  47.3
# 127    1           Zenit  20   7   3  58  17  67  14,307  24  27.5  55.1
#
#      SEASON
# 123    2015
# 124    2015
# 125    2015
# 126    2015
# 127    2015

# %%
RPL_Joint["LEAGUE"] = "RPL"

# %%
RPL_Joint.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RANK    128 non-null    object
#  1   TEAM    128 non-null    object
#  2   W       128 non-null    object
#  3   D       128 non-null    object
#  4   L       128 non-null    object
#  5   GF      128 non-null    object
#  6   GA      128 non-null    object
#  7   PTS     128 non-null    object
#  8   ATT     128 non-null    object
#  9   PL      128 non-null    object
#  10  AGE     128 non-null    object
#  11  POSS    128 non-null    object
#  12  SEASON  128 non-null    int64
#  13  LEAGUE  128 non-null    object
# dtypes: int64(1), object(13)
# memory usage: 14.1+ KB

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
x = (RPL_Joint.sort_values("RANK", ascending = True))["RANK"].astype(int)
y = (RPL_Joint.sort_values("RANK", ascending = True))["POSS"].astype(float)

# %%
sns.regplot(x,y);
# Out:
# /home/dyedbird/anaconda3/envs/classification/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
RPL_csv = RPL_Joint.to_csv(r'~/Documents/Metis_Fundamentals-main/Bootcamp/Regression/Module Project/RPL.csv', index = False)
